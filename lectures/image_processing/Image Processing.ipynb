# %%
from PIL import ImageColor
from PIL import Image
import matplotlib.pyplot as plt

# %%
cat = Image.open('cat_image.jpg')
cat.show()

# %%
new_image = Image.new('RGBA', (100, 100), 'black')
new_image.show()

# %%
cat.format, cat.size, cat.filename
# Out:
# ('JPEG', (474, 314), 'cat_image.jpg')

# %%
plt.imshow(cat)

# %%
# upper-left-x, upper-left-y, lower-right-x, lower-right-y
cropped = cat.crop((150, 180, 200, 250))
plt.imshow(cropped)

# %%
# Rotates in counter-clockwise direction
rotated = cat.rotate(90)
plt.imshow(rotated)

# %%
flipped = cat.transpose(Image.FLIP_LEFT_RIGHT)
plt.imshow(flipped)
